# %% [markdown]
# ## Spatial Autocorrelation and Regression Analysis
# In this tutorial, you will calculate a global Moran's I statistic to evaluate spatial autocorrelation in your data, and then explore different methods to account for spatial autocorrelation in your data. Specifically, we'll compare parameter estimates relating county income to 2016 county voting preferences using an OLS model, and autoregressive model, and an autocovariance function model.

# %%
# !pip install pysal
# !pip install libpysal
# !pip insall geopandas
# !pip install mlxtend
# Out:
# Requirement already satisfied: pysal in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (2.7.0)
# Requirement already satisfied: pointpats>=2.2.0 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from pysal) (2.2.0)
# Requirement already satisfied: spvcm>=0.3.0 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from pysal) (0.3.0)
# Requirement already satisfied: momepy>=0.5.3 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from pysal) (0.5.4)
# Requirement already satisfied: splot>=1.1.5.post1 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from pysal) (1.1.5.post1)
# Requirement already satisfied: access>=1.1.8 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from pysal) (1.1.8)
# Requirement already satisfied: libpysal>=4.6.2 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from pysal) (4.6.2)
# Requirement already satisfied: segregation>=2.3.1 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from pysal) (2.3.1)
# Requirement already satisfied: inequality>=1.0.0 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from pysal) (1.0.0)
# Requirement already satisfied: spaghetti>=1.6.6 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from pysal) (1.6.10)
# Requirement already satisfied: spint>=1.0.7 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from pysal) (1.0.7)
# Requirement already satisfied: spglm>=1.0.8 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from pysal) (1.0.8)
# Requirement already satisfied: spopt>=0.4.1 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from pysal) (0.4.1)
# Requirement already satisfied: spreg>=1.2.4 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from pysal) (1.3.0)
# Requirement already satisfied: giddy>=2.3.3 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from pysal) (2.3.3)
# Requirement already satisfied: mgwr>=2.1.2 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from pysal) (2.1.2)
# Requirement already satisfied: esda>=2.4.1 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from pysal) (2.4.3)
# Requirement already satisfied: tobler>=0.8.2 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from pysal) (0.9.0)
# Requirement already satisfied: mapclassify>=2.4.3 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from pysal) (2.4.3)
# Requirement already satisfied: geopandas in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from access>=1.1.8->pysal) (0.11.1)
# Requirement already satisfied: numpy>=1.3 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from access>=1.1.8->pysal) (1.21.5)
# Requirement already satisfied: pandas>=0.23.4 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from access>=1.1.8->pysal) (1.4.4)
# Requirement already satisfied: requests>=2 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from access>=1.1.8->pysal) (2.28.1)
# Requirement already satisfied: scipy>=0.11 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from esda>=2.4.1->pysal) (1.7.3)
# Requirement already satisfied: scikit-learn in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from esda>=2.4.1->pysal) (1.1.1)
# Requirement already satisfied: quantecon>=0.4.7 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from giddy>=2.3.3->pysal) (0.5.3)
# Requirement already satisfied: jinja2 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from libpysal>=4.6.2->pysal) (3.0.3)
# Requirement already satisfied: packaging in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from libpysal>=4.6.2->pysal) (21.3)
# Requirement already satisfied: appdirs in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from libpysal>=4.6.2->pysal) (1.4.4)
# Requirement already satisfied: beautifulsoup4 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from libpysal>=4.6.2->pysal) (4.11.1)
# Requirement already satisfied: networkx in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from mapclassify>=2.4.3->pysal) (2.8.4)
# Requirement already satisfied: tqdm>=4.27.0 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from momepy>=0.5.3->pysal) (4.64.1)
# Requirement already satisfied: pygeos in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from momepy>=0.5.3->pysal) (0.13)
# Requirement already satisfied: matplotlib in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from pointpats>=2.2.0->pysal) (3.5.2)
# Requirement already satisfied: opencv-contrib-python>=4.2.0 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from pointpats>=2.2.0->pysal) (4.6.0.66)
# Requirement already satisfied: seaborn in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from segregation>=2.3.1->pysal) (0.11.2)
# Requirement already satisfied: numba in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from segregation>=2.3.1->pysal) (0.56.4)
# Requirement already satisfied: rvlib>=0.0.5 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from segregation>=2.3.1->pysal) (0.0.6)
# Requirement already satisfied: pyproj>=3 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from segregation>=2.3.1->pysal) (3.4.0)
# Requirement already satisfied: deprecation in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from segregation>=2.3.1->pysal) (2.1.0)
# Requirement already satisfied: joblib in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from segregation>=2.3.1->pysal) (1.1.0)
# Requirement already satisfied: pip in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from segregation>=2.3.1->pysal) (22.2.2)
# Requirement already satisfied: quilt3 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from segregation>=2.3.1->pysal) (5.0.0)
# Requirement already satisfied: rtree in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from spaghetti>=1.6.6->pysal) (0.9.7)
# Requirement already satisfied: pulp in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from spopt>=0.4.1->pysal) (2.7.0)
# Requirement already satisfied: statsmodels in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from tobler>=0.8.2->pysal) (0.13.2)
# Requirement already satisfied: rasterio in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from tobler>=0.8.2->pysal) (1.2.10)
# Requirement already satisfied: rasterstats in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from tobler>=0.8.2->pysal) (0.17.0)
# Requirement already satisfied: shapely<2,>=1.7 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from geopandas->access>=1.1.8->pysal) (1.8.4)
# Requirement already satisfied: fiona>=1.8 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from geopandas->access>=1.1.8->pysal) (1.8.21)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from pandas>=0.23.4->access>=1.1.8->pysal) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from pandas>=0.23.4->access>=1.1.8->pysal) (2022.1)
# Requirement already satisfied: certifi in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from pyproj>=3->segregation>=2.3.1->pysal) (2022.9.24)
# Requirement already satisfied: sympy in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from quantecon>=0.4.7->giddy>=2.3.3->pysal) (1.11.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from requests>=2->access>=1.1.8->pysal) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from requests>=2->access>=1.1.8->pysal) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from requests>=2->access>=1.1.8->pysal) (3.3)
# Requirement already satisfied: PyYAML in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages/PyYAML-6.0-py3.10-linux-x86_64.egg (from rvlib>=0.0.5->segregation>=2.3.1->pysal) (6.0)
# Requirement already satisfied: cffi>=1.0.0 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from rvlib>=0.0.5->segregation>=2.3.1->pysal) (1.15.1)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from numba->segregation>=2.3.1->pysal) (0.39.1)
# Requirement already satisfied: setuptools in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from numba->segregation>=2.3.1->pysal) (63.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from scikit-learn->esda>=2.4.1->pysal) (2.2.0)
# Requirement already satisfied: soupsieve>1.2 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from beautifulsoup4->libpysal>=4.6.2->pysal) (2.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from jinja2->libpysal>=4.6.2->pysal) (2.1.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from matplotlib->pointpats>=2.2.0->pysal) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from matplotlib->pointpats>=2.2.0->pysal) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from matplotlib->pointpats>=2.2.0->pysal) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from matplotlib->pointpats>=2.2.0->pysal) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from matplotlib->pointpats>=2.2.0->pysal) (9.2.0)
# Requirement already satisfied: requests-futures==1.0.0 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from quilt3->segregation>=2.3.1->pysal) (1.0.0)
# Requirement already satisfied: jsonschema<5,>=3 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from quilt3->segregation>=2.3.1->pysal) (4.16.0)
# Requirement already satisfied: aws-requests-auth>=0.4.2 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from quilt3->segregation>=2.3.1->pysal) (0.4.3)
# Requirement already satisfied: jsonlines==1.2.0 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from quilt3->segregation>=2.3.1->pysal) (1.2.0)
# Requirement already satisfied: boto3>=1.10.0 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from quilt3->segregation>=2.3.1->pysal) (1.26.4)
# Requirement already satisfied: tenacity>=5.1.1 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from quilt3->segregation>=2.3.1->pysal) (8.1.0)
# Requirement already satisfied: six in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from jsonlines==1.2.0->quilt3->segregation>=2.3.1->pysal) (1.16.0)
# Requirement already satisfied: click>=4.0 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from rasterio->tobler>=0.8.2->pysal) (8.0.4)
# Requirement already satisfied: attrs in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from rasterio->tobler>=0.8.2->pysal) (21.4.0)
# Requirement already satisfied: cligj>=0.5 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from rasterio->tobler>=0.8.2->pysal) (0.7.2)
# Requirement already satisfied: affine in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from rasterio->tobler>=0.8.2->pysal) (2.3.0)
# Requirement already satisfied: snuggs>=1.4.1 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from rasterio->tobler>=0.8.2->pysal) (1.4.7)
# Requirement already satisfied: click-plugins in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from rasterio->tobler>=0.8.2->pysal) (1.1.1)
# Requirement already satisfied: simplejson in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from rasterstats->tobler>=0.8.2->pysal) (3.17.6)
# Requirement already satisfied: patsy>=0.5.2 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from statsmodels->tobler>=0.8.2->pysal) (0.5.2)
# Requirement already satisfied: botocore<1.30.0,>=1.29.4 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from boto3>=1.10.0->quilt3->segregation>=2.3.1->pysal) (1.29.4)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from boto3>=1.10.0->quilt3->segregation>=2.3.1->pysal) (1.0.1)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from boto3>=1.10.0->quilt3->segregation>=2.3.1->pysal) (0.6.0)
# Requirement already satisfied: pycparser in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from cffi>=1.0.0->rvlib>=0.0.5->segregation>=2.3.1->pysal) (2.21)
# Requirement already satisfied: munch in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from fiona>=1.8->geopandas->access>=1.1.8->pysal) (2.5.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from jsonschema<5,>=3->quilt3->segregation>=2.3.1->pysal) (0.18.0)
# Requirement already satisfied: mpmath>=0.19 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages/mpmath-1.2.1-py3.10.egg (from sympy->quantecon>=0.4.7->giddy>=2.3.3->pysal) (1.2.1)
# Requirement already satisfied: libpysal in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (4.6.2)
# Requirement already satisfied: appdirs in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from libpysal) (1.4.4)
# Requirement already satisfied: packaging in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from libpysal) (21.3)
# Requirement already satisfied: pandas in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from libpysal) (1.4.4)
# Requirement already satisfied: requests in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from libpysal) (2.28.1)
# Requirement already satisfied: beautifulsoup4 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from libpysal) (4.11.1)
# Requirement already satisfied: numpy>=1.3 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from libpysal) (1.21.5)
# Requirement already satisfied: scipy>=0.11 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from libpysal) (1.7.3)
# Requirement already satisfied: jinja2 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from libpysal) (3.0.3)
# Requirement already satisfied: soupsieve>1.2 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from beautifulsoup4->libpysal) (2.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from jinja2->libpysal) (2.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from packaging->libpysal) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from pandas->libpysal) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from pandas->libpysal) (2022.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from requests->libpysal) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from requests->libpysal) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from requests->libpysal) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from requests->libpysal) (3.3)
# Requirement already satisfied: six>=1.5 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas->libpysal) (1.16.0)
# ERROR: unknown command "insall" - maybe you meant "install"
# Collecting mlxtend
#   Downloading mlxtend-0.21.0-py2.py3-none-any.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 25.5 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: numpy>=1.16.2 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from mlxtend) (1.21.5)
# Requirement already satisfied: joblib>=0.13.2 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from mlxtend) (1.1.0)
# Requirement already satisfied: setuptools in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from mlxtend) (63.4.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from mlxtend) (1.1.1)
# Requirement already satisfied: matplotlib>=3.0.0 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from mlxtend) (3.5.2)
# Requirement already satisfied: scipy>=1.2.1 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from mlxtend) (1.7.3)
# Requirement already satisfied: pandas>=0.24.2 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from mlxtend) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.2)
# Requirement already satisfied: pillow>=6.2.0 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (21.3)
# Requirement already satisfied: pytz>=2020.1 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from pandas>=0.24.2->mlxtend) (2022.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from scikit-learn>=1.0.2->mlxtend) (2.2.0)
# Requirement already satisfied: six>=1.5 in /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.21.0

# %%
import pysal as ps
import numpy as np
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from libpysal.weights.contiguity import Queen
import libpysal
from splot.libpysal import plot_spatial_weights
from splot.esda import moran_scatterplot
from splot.esda import plot_moran
from esda.moran import Moran_Local
from esda.moran import Moran
from statsmodels.api import OLS
from pysal.model import spreg
sns.set_style('white')

# %% [markdown]
# First, we're going to open 'Elections' dataset from the Geodata Center at the University of Chicago.
#
# * More on spatial data science resources from UC: https://spatial.uchicago.edu/
# * A list of datasets available through lipysal: https://geodacenter.github.io/data-and-lab//
#
# Using our multicollinearity.ipynb, we downloaded this dataset to *H:/EnvDatSci/election/election.shp*
#
# **Note: it may be on a different location on your computer**
#
# ### TASK 1: access the "election" shapefile used in the multicollinearity.ipnb script

# %%
# Task 1
from libpysal.examples import load_example
elections = load_example('Elections')
votes = gpd.read_file("/home/bmferro/pysal_data/Elections/election/election.shp")
# Out:
# Example not available: Elections
# Example not downloaded: Chicago parcels
# Example not downloaded: Chile Migration
# Example not downloaded: Spirals

# %%
#Let's view the shapefile to get a general idea of the geometry we're looking at:
# %matplotlib inline
votes.plot()
# Out:
# <AxesSubplot:>

# %%
#View the first few line]s of the dataset
votes.head()
# Out:
#   STATEFP COUNTYFP  GEOID         ALAND      AWATER       area_name  \
# 0      01      005  01005  2.291821e+09  50864677.0  Barbour County
# 1      01      023  01023  2.365955e+09  19059247.0  Choctaw County
# 2      01      035  01035  2.201896e+09   6643480.0  Conecuh County
# 3      01      051  01051  1.601877e+09  99850740.0   Elmore County
# 4      01      065  01065  1.667805e+09  32525874.0     Hale County
#
#   state_abbr  PST045214  PST040210  PST120214  ...  total_2012  Demvotes12  \
# 0         AL    26887.0    27457.0       -2.1  ...     11459.0      5873.0
# 1         AL    13323.0    13858.0       -3.9  ...      7965.0      3785.0
# 2         AL    12670.0    13228.0       -4.2  ...      7013.0      3551.0
# 3         AL    80977.0    79296.0        2.1  ...     35440.0      8940.0
# 4         AL    15184.0    15760.0       -3.7  ...      8628.0      5401.0
#
#    GOPvotes12  county_fip  state_fips  pct_dem_12  pct_gop_12  diff_2012  \
# 0      5539.0         5.0         1.0    0.512523    0.483376      334.0
# 1      4150.0        23.0         1.0    0.475204    0.521030      365.0
# 2      3434.0        35.0         1.0    0.506345    0.489662      117.0
# 3     26223.0        51.0         1.0    0.252257    0.739927    17283.0
# 4      3205.0        65.0         1.0    0.625985    0.371465     2196.0
#
#    pct_pt_12                                           geometry
# 0   0.029147  POLYGON ((-85.748 31.619, -85.745 31.619, -85....
# 1  -0.045825  POLYGON ((-88.473 31.894, -88.469 31.930, -88....
# 2   0.016683  POLYGON ((-87.427 31.264, -87.426 31.268, -87....
# 3  -0.487669  POLYGON ((-86.413 32.751, -86.371 32.751, -86....
# 4   0.254520  POLYGON ((-87.870 32.762, -87.868 32.766, -87....
#
# [5 rows x 75 columns]

# %% [markdown]
# In our multicollinearity notebook, we visualized the voting trends, and the change in voting trends, in space. First we created a new column indicating the percent change in democratic vote. Then we plotted the percent democratic vote in 2012, the percent democratic vote in 2016, and the percent change in democratic vote as maps and using global histograms.

# %%
# Add new column pct_dem_change to votes:
votes['pct_dem_change'] = votes['pct_dem_12'] - votes['pct_dem_16']

f,ax = plt.subplots(3,2, figsize=(1.6*6 + 1,4.2*3), gridspec_kw=dict(width_ratios=(6,1)))
for i,col in enumerate(['pct_dem_12','pct_dem_16', 'pct_dem_change']):
    votes.plot(col, linewidth=.05, cmap='RdBu', ax=ax[i,0])
    ax[i,0].set_title(['2012','2016', '2012-2016 change'][i] + "% democratic vote")
    ax[i,0].set_xticklabels('')
    ax[i,0].set_yticklabels('')
    sns.kdeplot(votes[col].values, ax=ax[i,1], vertical=True, shade=True, color='slategrey')
    ax[i,1].set_xticklabels('')
    ax[i,1].set_ylim(-1,1)
f.tight_layout()
plt.show()
# Out:
# /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages/seaborn/distributions.py:1689: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages/seaborn/distributions.py:1689: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages/seaborn/distributions.py:1689: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Spatial Autocorrelation
# From https://www.sciencedirect.com/topics/computer-science/spatial-autocorrelation
#
# >"Spatial autocorrelation is the term used to describe the presence of *systematic* spatial variation in a variable and positive spatial autocorrelation, which is most often encountered in practical situations, is the tendency for areas or sites that are close together to have similar values."

# %% [markdown]
# ### TASK 2: Do you see evidence for *spatial autocorrelation* in the three plots above? If so, describe the evidence that you see.
#
# Yes, there is spatial autocorrelation occurring in southern California. From mid to south California, there are changes toward a decrease in democratic votes.

# %% [markdown]
# ## Was the county wide percent change in democratic vote related to per capita income?
# The next question is how can we use robust statistics to determine whether per capita income or the county land area were related to a change in 2016 voting preferences. To do this, we're going to conduct a linear regression relating our parameters pct_dem_change to INC910213 and ALAND. Then, we're going to use the confidence interval around beta hat (our slope parameter estimate) to determine whether the relationships between INC910213, ALAND, and pct_dem_change are significantly different than zero.
#
# First we're going to visualize how these variables relate in the global data:

# %%
votes.dropna(subset=['pct_dem_12','pct_dem_16'], inplace=True)

# %%
f,ax = plt.subplots(1,4, figsize=(4*3.1,4))

votes[['pct_dem_12','pct_dem_16']].plot.scatter('pct_dem_12','pct_dem_16', ax=ax[0])
ax[0].set_xlabel('2012 Two Party Vote (% Dem)')
ax[0].set_ylabel('2016 Two Party Vote (% Dem)')
print(np.corrcoef(votes['pct_dem_12'].values, votes['pct_dem_16'].values)[0,1])


votes[['INC910213','pct_dem_change']].plot.scatter('INC910213','pct_dem_change', ax=ax[1])
ax[1].set_xlabel('Per capita income')
ax[1].set_ylabel('% Change in Democratic Vote')
print(np.corrcoef(votes['pct_dem_change'].values, votes['INC910213'].values)[0,1])

votes[['ALAND','pct_dem_change']].plot.scatter('ALAND','pct_dem_change', ax=ax[2])
ax[2].set_xlabel('County land area')
ax[2].set_ylabel('% Change in Democratic Vote')
print(np.corrcoef(votes['pct_dem_change'].values, votes['ALAND'].values)[0,1])

votes[['INC910213','ALAND']].plot.scatter('INC910213','ALAND', ax=ax[3])
ax[3].set_xlabel('Per capita income')
ax[3].set_ylabel('County land area')
print(np.corrcoef(votes['INC910213'].values, votes['ALAND'].values)[0,1])

f.tight_layout()
plt.show()
# Out:
# 0.9464235104255706
# -0.24471033010257184
# -0.08312272316914267
# -0.014495571366592337

# %% [markdown]
# ### TASK 3: Do we have significant collinearity in our data?
#
# Significant collinearity is found in the 2012 and 2016 Two Party Vote (% Dem)

# %% [markdown]
# What we're looking at in the first plot is the 2012 percent democratic vote, the second plot is the 2016 percent democratic vote, the third plot is the 2012 and 2016 percent democratic vote. In the fourth plot, we're looking at how per capital income (x axis) relates to % change in democratic vote. We want to establish a trendline in the fourth plot using linear regression, and determine of the slope in that trendline is statistically significant.
#
# ### TASK 4: what are some features of this data that it look well-suited for linear regression? What are some features of this data that make it poorly suited for linear regression?
#
# Broad collection of data is well-suited, though spatial autocorrelation is poorly suited for regression.

# %% [markdown]
# ## Do we have spatial autocorrelation in our data?
# When we're looking at distributions of voting preferences, remember that we're aggregating these numbers over arbitrary (er...political) geographic regions.
#
# Each column in that dataframe represents a data value summarized over a US county, but US counties have widely different land areas and populations:

# %%
f,ax = plt.subplots(1,2, figsize=(2*3*1.6, 2))
sns.kdeplot(votes['ALAND'].values, shade=True, color='slategrey', ax=ax[0])
ax[0].set_xlabel('County Land Area')

sns.kdeplot(votes['PST045214'].values, shade=True, color='slategrey', ax=ax[1])
ax[1].set_xlabel('2014 County Population')
# Out:
# Text(0.5, 0, '2014 County Population')

# %% [markdown]
# Our *spatial sampling rate* (by county) may not accurately represent the spatial frequency of variability in voting preferences and/or income.
#
# First, let's focus on the spatial componnet: the fact that these counties are different sizes.
#
# If we want to identify spatial autocorrelation in our data, we need to first understand how this spatial autocorrelation decays as a function of distance.
#
# To do this, we calculate the Moran's I statistic, which you can think of as the "slope" that we'd get when we regress data values for all geographic entities with data values that neighbor within a given distance. Lets look at our data in lat/lon space again:

# %%
votes.plot()
# Out:
# <AxesSubplot:>

# %%
votes.crs
# Out:
# <Derived Projected CRS: PROJCS["Equidistant_Cylindrical",GEOGCS["WGS 84",D ...>
# Name: Equidistant_Cylindrical
# Axis Info [cartesian]:
# - [east]: Easting (Meter)
# - [north]: Northing (Meter)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: unnamed
# - method: Equidistant Cylindrical
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# ### TASK 5: What is the horizontal unit (unit of distance) in our votes data?
#
# The unit of distance in the votes data is meters.

# %% [markdown]
# One issue is that we're sampling spatially at a distinct, and heterogenous, granulatiry. The smallest unit of measurement available in our dataset is the county level. Counties are different sizes. How can we evaluate whether this spatial sampling granularity is of sufficient resolution to capture the scale of variability in our dataset?
#
# * If we are sampling at too course of a spatial scale, we run the risk of missing key patterns of variability in our data (**UNDERSAMPLING**)
#
# * If we are sampling at too fine of a sptial scale, we run the risk of violating assumptions of independence between our individual observations (**OVERSAMPLING**)
#
# ### TASK 6: In your own words, describe how the spatial sampling scale of "county" might represent and oversampling or undersampling of data as it relates to our question (did per capita income or land area impact change in voting preference
#
# In the spatial sampling, what may be occuring is undersampling in large counties. If the sample size is the same, you would be taking a lesser percentage of people within the county into account. Oversampling would also be occurring as small counties would be taking a much higher percentage of people within the county into account.

# %% [markdown]
# ## Calculating a weights matrix:
# The first thing we want to tackle is a quantification of any spatial autocorrelation in our dataset. Spatial autocorrelation inflates our theoretical number of samples (N), artificially increasing the power in our test statistics. In other words, when we're calculating test statistics, spatial autocorrelation in our data can make it seem like parameters that are unimportant are actually significant.
#
# Since we're dealing with a heterogeneous sampling grid in our data, the first thing we want to do is calculate a weights matrix.
#
# We're going to use the Queen function in pysal to do this. Full documentation here: https://pysal.org/libpysal/generated/libpysal.weights.Queen.html
#
# Or just use the built in help with the function below:

# %%
??Queen

#Click the "X" in the upper right corner of that help window that pops up to close it.

# %%
#Calculate weights object
weights = Queen.from_dataframe(votes)

#Use built in plot function to visualize how the weights matrix works
plot_spatial_weights(weights, votes)
plt.show()
# Out:
# /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages/libpysal/weights/weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 4 disconnected components.
#  There are 3 islands with ids: 1267, 2729, 2763.
#   warnings.warn(message)

# %% [markdown]
# The verticies in this plot represent two things:
# * First, they link "neigbors" based on the model parameters we set for defining neighborhood (here we use the defaul settings and consider any contiguous polygons).
# * The length of the verticies indicates the distance between the centers of neighborhing cells.
#
# "Neighbors" that are father matter less than "neighbors" that are closer in identifying the strength of spatial autocorrelation.
#
# ## Calculate Moran's I:
# Moran's I statistic quantifies the spatial autocorrelation in your data. From https://en.wikipedia.org/wiki/Moran%27s_I
# >"Spatial dependency leads to the spatial autocorrelation problem in statistics since, like temporal autocorrelation, this violates standard statistical techniques that assume independence among observations. For example, regression analyses that do not compensate for spatial dependency can have unstable parameter estimates and yield unreliable significance tests. Spatial regression models (see below) capture these relationships and do not suffer from these weaknesses. It is also appropriate to view spatial dependency as a source of information rather than something to be corrected."

# %%
# calculate Moran and plot
moran_votes = Moran(votes['pct_dem_change'], w=weights)
plot_moran(moran_votes, zstandard=True, figsize=(10,4))
plt.show()
# Out:
# ('WARNING: ', 1267, ' is an island (no neighbors)')
# ('WARNING: ', 2729, ' is an island (no neighbors)')
# ('WARNING: ', 2763, ' is an island (no neighbors)')

# %%
# calculate Moran and plot
moran_land = Moran(votes['ALAND'], w=weights)
plot_moran(moran_land, zstandard=True, figsize=(10,4))
plt.show()

# %% [markdown]
# ### TASK 6: Do we have statistically significant evidence (at alpha = 0.05) of spatial autocorrelation in our response variable (Percent change in democratic vote, or pct_pt_16)?
# Use code cell below as your "calculator".
#
# * We can conclude that there is significant positive spatial autocorrelation due to the p-values being <0.05 and a Moran I value > -1/(N-1)

# %%
# What is the null hypothesis? Moran's I = 0
# What is the alternative hypothesis? Moran's I does not equal zero
# What is our test statistic? We can chose one of several test statistics, p-norm (p-value under normalization assumption), or p-rand (p-value under randomization)
# How can we derive the test statistic from our "moran" object?
# HINT
print(moran_votes.p_norm)
# Out:
# 0.0

# %% [markdown]
# ## Caluculate a linear regression on the global data:
# In this next step, we're going to calculate a linear regression in our data an determine whether that analysis determines a statistically significant relationship between our percent income and percent change in democratic vote.

# %%
#first, forumalate the model. See weather_trend.py in "Git_101" for a refresher on how.
from mlxtend.preprocessing import standardize

#extract variable that you want to use to "predict"
X_raw = np.array(votes[['INC910213', 'ALAND']].values)
X = standardize(X_raw, columns=[0, 1])


#extract variable that we want to "predict"
Y = np.array(votes['pct_dem_change'].values)
# standardize them (calculate z-score) to help interpret coefficient magnitude
#Y = (Y - Y.mean())/Y.std()
Y= standardize(Y)

lm = OLS(Y,X)
lm_results = OLS(Y,X).fit().summary()

# %%
print(lm_results)
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.067
# Model:                            OLS   Adj. R-squared (uncentered):              0.067
# Method:                 Least Squares   F-statistic:                              112.2
# Date:                Fri, 11 Nov 2022   Prob (F-statistic):                    8.70e-48
# Time:                        09:52:47   Log-Likelihood:                         -4301.6
# No. Observations:                3108   AIC:                                      8607.
# Df Residuals:                    3106   BIC:                                      8619.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.2460      0.017    -14.193      0.000      -0.280      -0.212
# x2            -0.0867      0.017     -5.002      0.000      -0.121      -0.053
# ==============================================================================
# Omnibus:                       64.089   Durbin-Watson:                   1.371
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               63.996
# Skew:                           0.326   Prob(JB):                     1.27e-14
# Kurtosis:                       2.739   Cond. No.                         1.01
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### TASK 7: Do we have statistically significant evidence (at alpha = 0.05) of a statistically significant relationship between pct_dem_change and INC910213 and ALAND? How does INC910213 and ALAND impact pct_dem_change? Use numbers to back your claim.
#
# * We have a statistically significant relationship between the percent change in democratic votes by county and  INC910213 and ALAND.
# * The relationship and predictive ability between the variables involve are very weak, with an R^2 value of 0.067

# %% [markdown]
# Now, let's plot our residuals to see if there are any spatial patterns in them.
#
# Remember residuals = predicted - fitted values

# %%
#Add model residuals to our "votes" geopandas dataframe:
votes['lm_resid']=lm.fit().resid

# %% [markdown]
# Remember, in OLS regression we depend out our residuals being normally distributed:

# %%
sns.kdeplot(votes['lm_resid'].values, shade=True, color='slategrey')
ax[1].set_xlabel('OLS residuals')
# Out:
# Text(0.5, 24.0, 'OLS residuals')

# %%
#Plot them in space:
votes.plot('lm_resid', linewidth=.05, cmap='RdBu')
# Out:
# <AxesSubplot:>

# %% [markdown]
# These are very not normal residuals. What's going on?
#
# ### TASK 8: What does a positive residual mean here (the model overpredicted change in democratic vote, the model underpredicted change in democratic vote)?
#
# * A positive residual in this case means that the model overpredicted the change in democratic votes, otherwise stated as predicting a higher positive change than what actually happened.
#
# One way we can evaluate whether spatial autocorrelation has impacted our results is if we see spatial autocorrelation in the residuals:

# %%
# calculate Moran and plot
moran = Moran(votes['lm_resid'], w=weights)
plot_moran(moran, zstandard=True, figsize=(10,4))
plt.show()

# %% [markdown]
# ### TASK 9: Do we have correlated residuals (use numbers to back your answer)?
#
# * We have significantly correlated residuals, with slightly higher positive autocorrelation than what was actually seen.

# %%
print(moran.p_norm)
# Out:
# 0.0

# %%
f,ax = plt.subplots(1,3, figsize=(3*3*1.6, 2))

votes[['INC910213','lm_resid']].plot.scatter('INC910213','lm_resid', ax=ax[0])
ax[0].set_xlabel('county income')
ax[0].set_ylabel('linear model residuals')

votes[['ALAND','lm_resid']].plot.scatter('ALAND','lm_resid', ax=ax[1])
ax[1].set_xlabel('county land area')
ax[1].set_ylabel('linear model residuals')

votes[['pct_dem_change','lm_resid']].plot.scatter('pct_dem_change','lm_resid', ax=ax[2])
ax[2].set_xlabel('2012-2016 change in % democratic vote')
ax[2].set_ylabel('linear model residuals')
# Out:
# Text(0, 0.5, 'linear model residuals')

# %% [markdown]
# *The first two plots show heteroskedasticity in our residuals. The second plot shows bias in our model*

# %% [markdown]
# ## Autocovariate regression: spatial lag model
# Let's see if we can get different answers by accounting for our residuals in our model. First, we'll try a spatial lag model. A spatial lag model is a type of autocovariate model that assumes that dependencies exist directly among the levels of the dependent variable, and models them as an "autocovariate". So we create an autocovariate function that describes the degree to which the percent change in democratic vote at one location is affected by the percent change in democratic vote at the nearby locations. The coefficient and p-value for the autocovariate function are interpreted as for the independent variables.

# %%
# ?spreg.ML_Lag

# %%
Yl = Y.T
Yl.shape = (len(Y),1)

lag=spreg.ML_Lag(Yl, X, weights, name_x=["income", "area"],name_y="vote", name_w="weights")
print(lag.summary)
# Out:
# /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages/scipy/optimize/_minimize.py:783: RuntimeWarning: Method 'bounded' does not support relative tolerance in x; defaulting to absolute tolerance.
#   warn("Method 'bounded' does not support relative tolerance in x; "
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: MAXIMUM LIKELIHOOD SPATIAL LAG (METHOD = FULL)
# -----------------------------------------------------------------
# Data set            :     unknown
# Weights matrix      :     weights
# Dependent Variable  :        vote                Number of Observations:        3108
# Mean dependent var  :     -0.0000                Number of Variables   :           4
# S.D. dependent var  :      1.0002                Degrees of Freedom    :        3104
# Pseudo R-squared    :      0.6739
# Spatial Pseudo R-squared:  0.0119
# Sigma-square ML     :       0.341                Log likelihood        :   -3005.539
# S.E of regression   :       0.584                Akaike info criterion :    6019.079
#                                                  Schwarz criterion     :    6043.246
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT       0.0001480       0.0104726       0.0141321       0.9887246
#               income      -0.1853466       0.0117099     -15.8282257       0.0000000
#                 area      -0.0148548       0.0105011      -1.4146028       0.1571850
#               W_vote       0.8188915       0.0108128      75.7335286       0.0000000
# ------------------------------------------------------------------------------------
# ================================ END OF REPORT =====================================

# %%
#Add model residuals to our "votes" geopandas dataframe:
votes['slm_resid']=lag.u
sns.kdeplot(votes['slm_resid'].values, shade=True, color='slategrey')
ax[1].set_xlabel('SLM residuals')
# Out:
# Text(0.5, 24.0, 'SLM residuals')

# %%
# calculate Moran and plot
moran = Moran(votes['slm_resid'], w=weights)
plot_moran(moran, zstandard=True, figsize=(10,4))
plt.show()

# %%
#Plot them in spac:
votes.plot('slm_resid', linewidth=.05, cmap='RdBu')
# Out:
# <AxesSubplot:>

# %%
# calculate Moran and plot
moran = Moran(votes['slm_resid'], w=weights)
plot_moran(moran, zstandard=True, figsize=(10,4))
plt.show()

# %%
moran.p_norm
# Out:
# 0.16744049406955175

# %%
f,ax = plt.subplots(1,3, figsize=(3*3*1.6, 2))

votes[['INC910213','slm_resid']].plot.scatter('INC910213','slm_resid', ax=ax[0])
ax[0].set_xlabel('Per capita income')
ax[0].set_ylabel('spatial lag model residuals')

votes[['ALAND','slm_resid']].plot.scatter('ALAND','slm_resid', ax=ax[1])
ax[1].set_xlabel('county land area')
ax[1].set_ylabel('spatial lag model residuals')

votes[['pct_dem_change','slm_resid']].plot.scatter('pct_dem_change','slm_resid', ax=ax[2])
ax[2].set_xlabel('2012-2016 change in % democratic vote')
ax[2].set_ylabel('spatial lag model residuals')
# Out:
# Text(0, 0.5, 'spatial lag model residuals')

# %% [markdown]
# ### TASK 10: When we account for spatial autocorrelation in our data using the spatial lag model, do we still see a significant relationship between our response and predictor variables? Do you think this is a valid approach? Why or why not?
#
# * We still see a significant relationship between our response and predictor variables.
# * I believe this is a valid approach, although lacking to account for other significant factors. It corrects autcorrelation, although the residuals are still affected by per capita income. This could be dealt with using weighted least squares regression.
#
#
#
# ## Spatial autoregressive model (maximum likelihood spatial error model)
# Instead of modelling spatial dependence using an autocovariate, we use a similar type of weight structure (here called "lambda") to weight the error matrix:

# %%
MLerror = spreg.ML_Error(Yl, X, weights, name_x=["income", "area"],name_y="vote", name_w="weights")
print(MLerror.summary)
# Out:
# /home/bmferro/miniconda3/envs/myenv/lib/python3.10/site-packages/scipy/optimize/_minimize.py:783: RuntimeWarning: Method 'bounded' does not support relative tolerance in x; defaulting to absolute tolerance.
#   warn("Method 'bounded' does not support relative tolerance in x; "
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: MAXIMUM LIKELIHOOD SPATIAL ERROR (METHOD = FULL)
# -------------------------------------------------------------------
# Data set            :     unknown
# Weights matrix      :     weights
# Dependent Variable  :        vote                Number of Observations:        3108
# Mean dependent var  :     -0.0000                Number of Variables   :           3
# S.D. dependent var  :      1.0002                Degrees of Freedom    :        3105
# Pseudo R-squared    :      0.0617
# Sigma-square ML     :       0.311                Log likelihood        :   -2883.754
# S.E of regression   :       0.558                Akaike info criterion :    5773.508
#                                                  Schwarz criterion     :    5791.633
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT      -0.0167613       0.0616425      -0.2719117       0.7856899
#               income      -0.3506494       0.0143652     -24.4097120       0.0000000
#                 area      -0.0156373       0.0160705      -0.9730408       0.3305330
#               lambda       0.8402223       0.0112220      74.8730927       0.0000000
# ------------------------------------------------------------------------------------
# ================================ END OF REPORT =====================================

# %%
#Add model residuals to our "votes" geopandas dataframe:
votes['mlError_resid']=MLerror.u
sns.kdeplot(votes['mlError_resid'].values, shade=True, color='slategrey')
ax[1].set_xlabel('MLError residuals')
# Out:
# Text(0.5, 24.0, 'MLError residuals')

# %%
#Plot them in spac:
votes.plot('mlError_resid', linewidth=.05, cmap='RdBu')
# Out:
# <AxesSubplot:>

# %%
# calculate Moran and plot
moran = Moran(votes['mlError_resid'], w=weights)
plot_moran(moran, zstandard=True, figsize=(10,4))
plt.show()

# %%
moran.p_norm
# Out:
# 0.0

# %%
f,ax = plt.subplots(1,3, figsize=(3*3*1.6, 2))

votes[['INC910213','mlError_resid']].plot.scatter('INC910213','mlError_resid', ax=ax[0])
ax[0].set_xlabel('Per capita income')
ax[0].set_ylabel('autoregressive model residuals')

votes[['ALAND','mlError_resid']].plot.scatter('ALAND','mlError_resid', ax=ax[1])
ax[1].set_xlabel('county land area')
ax[1].set_ylabel('autoregressive model residuals')

votes[['pct_dem_change','mlError_resid']].plot.scatter('pct_dem_change','mlError_resid', ax=ax[2])
ax[2].set_xlabel('2012-2016 change in % democratic vote')
ax[2].set_ylabel('autoregressive model residuals')
# Out:
# Text(0, 0.5, 'autoregressive model residuals')

# %% [markdown]
# ### TASK 11: Given these three models, do you believe that there is a linear relationship between percent change in democratic vote and income level? What about between change in democratic vote and land area? Why or why not?
#
# * Based on the models, there is a linear relationship between pct_dem_change and income level. Not only was this variable significant in the models, but it also causes a variable variance in OLS residuals. This leads me to believe there is further regression analysis and correction that can be done to determine the best way to estimate this strong relationship.
#
# * Regarding pct_dem_change and land area, there is not a linear relationship. After removal of spatial autocorrelation, this variable was found to be no longer significant. This leads to the conclusion that, while land area may have a small measure of influence on this change, it does not significantly impact the change across the U.S.
